# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, cross_validate
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             roc_auc_score, confusion_matrix, classification_report,
                             ConfusionMatrixDisplay, roc_curve, auc)
from sklearn.utils.class_weight import compute_class_weight

# %%
# Load and shuffle data to prevent ordered outcomes
data = pd.read_csv('/Users/puchku-home/Study/PROJECT/EEG/TIME FEATURES OUTPUTS/timefeature_data.csv')
data = data.sample(frac=1, random_state=42).reset_index(drop=True)  # Critical shuffle

# Verify class distribution after shuffling
print("Class distribution after shuffling:")
print(data['target'].value_counts(normalize=True))

# Split features and target
X = data.drop('target', axis=1)
y = data['target']
# Out:
# Class distribution after shuffling:
# target
# 1    0.500061
# 0    0.499939
# Name: proportion, dtype: float64

# %%
# First split: 80% train-val, 20% test
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y, 
    test_size=0.2,
    stratify=y
)

print(f"\nTrain-val size: {len(X_trainval)}, Test size: {len(X_test)}")
print("Test set class distribution:", np.unique(y_test, return_counts=True))
# Out:
# Train-val size: 13105, Test size: 3277
# Test set class distribution: (array([0, 1]), array([1638, 1639]))

# %%
param_grid = {
    'learning_rate': [0.05, 0.1],
    'max_iter': [100, 300],
    'max_depth': [3, None],
    'max_leaf_nodes': [15, 31],
    'min_samples_leaf': [20, 50],
    'l2_regularization': [0.0, 0.1],
    'max_bins': [128, 255],
    'early_stopping': [True]
}

model = HistGradientBoostingClassifier(
    class_weight='balanced',
    random_state=42,
    n_iter_no_change=10,
    validation_fraction=0.1,
    verbose=1
)

# Inner CV for grid search
inner_cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=inner_cv,
    scoring='roc_auc',
    n_jobs=-1,
    verbose=2
)

grid_search.fit(X_trainval, y_trainval)
best_model = grid_search.best_estimator_
# Out:
# Fitting 3 folds for each of 128 candidates, totalling 384 fits
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.178 s
# Binning 0.002 GB of validation data: 0.005 s
# Fitting gradient boosted rounds:
# 0.181 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.163 s
# Binning 0.002 GB of validation data: 0.191 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.196 s
# Binning 0.002 GB of validation data: 0.196 s
# Binning 0.002 GB of validation data: 0.005 s
# 0.201 s
# Binning 0.002 GB of validation data: Fitting gradient boosted rounds:
# 0.003 s
# 0.197 s
# Binning 0.002 GB of validation data: Fitting gradient boosted rounds:
# 0.004 s
# Fitting gradient boosted rounds:
# 0.005 s
# Fitting gradient boosted rounds:
# 0.004 s
# Fitting gradient boosted rounds:
# 0.199 s
# Binning 0.002 GB of validation data: 0.005 s
# Fitting gradient boosted rounds:
# 0.187 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.198 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.162 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Fit 100 trees in 0.651 s, (795 total leaves)
# Time spent computing histograms: 0.242s
# Time spent finding best splits:  0.086s
# Time spent applying splits:      0.013s
# Time spent predicting:           0.001s
# Fit 100 trees in 0.662 s, (779 total leaves)
# Time spent computing histograms: 0.274s
# Time spent finding best splits:  0.086s
# Time spent applying splits:      0.015s
# Time spent predicting:           0.002s
# Fit 100 trees in 0.669 s, (798 total leaves)
# Time spent computing histograms: 0.264s
# Time spent finding best splits:  0.088s
# Time spent applying splits:      0.013s
# Time spent predicting:           0.001s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   0.7s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   0.7s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   0.7s
# Fit 100 trees in 0.639 s, (795 total leaves)
# Time spent computing histograms: 0.276s
# Time spent finding best splits:  0.091s
# Time spent applying splits:      0.015s
# Time spent predicting:           0.002s
# Fit 100 trees in 0.705 s, (781 total leaves)
# Time spent computing histograms: 0.273s
# Time spent finding best splits:  0.084s
# Time spent applying splits:      0.018s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   0.7s
# Fit 100 trees in 0.714 s, (786 total leaves)
# Time spent computing histograms: 0.274s
# Time spent finding best splits:  0.096s
# Time spent applying splits:      0.018s
# Time spent predicting:           0.001s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   0.7s
# Fit 100 trees in 0.728 s, (798 total leaves)
# Time spent computing histograms: 0.289s
# Time spent finding best splits:  0.093s
# Time spent applying splits:      0.017s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   0.8s
# Fit 100 trees in 0.742 s, (782 total leaves)
# Time spent computing histograms: 0.307s
# Time spent finding best splits:  0.090s
# Time spent applying splits:      0.016s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   0.8s
# Fit 100 trees in 0.644 s, (779 total leaves)
# Time spent computing histograms: 0.274s
# Time spent finding best splits:  0.090s
# Time spent applying splits:      0.016s
# Time spent predicting:           0.001s
# Fit 100 trees in 0.761 s, (786 total leaves)
# Time spent computing histograms: 0.319s
# Time spent finding best splits:  0.096s
# Time spent applying splits:      0.018s
# Time spent predicting:           0.001s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   0.7s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   0.8s
# Binning 0.016 GB of training data: Fit 100 trees in 0.645 s, (781 total leaves)
# Time spent computing histograms: 0.271s
# Time spent finding best splits:  0.083s
# Time spent applying splits:      0.014s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   0.8s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   0.7s
# Fit 100 trees in 0.620 s, (782 total leaves)
# Time spent computing histograms: 0.283s
# Time spent finding best splits:  0.087s
# Time spent applying splits:      0.016s
# Time spent predicting:           0.002s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   0.7s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.181 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.173 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.200 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.174 s
# Binning 0.002 GB of validation data: 0.007 s
# Fitting gradient boosted rounds:0.147 s
# Binning 0.002 GB of validation data:
# 0.003 s
# Fitting gradient boosted rounds:
# 0.181 s
# Binning 0.002 GB of validation data: 0.158 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.005 s
# Fitting gradient boosted rounds:
# 0.172 s
# Binning 0.002 GB of validation data: 0.176 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.003 s
# Fitting gradient boosted rounds:
# 0.172 s
# Binning 0.002 GB of validation data: 0.178 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.004 s
# Fitting gradient boosted rounds:
# 0.168 s
# Binning 0.002 GB of validation data: 0.007 s
# Fitting gradient boosted rounds:
# Fit 300 trees in 1.368 s, (2367 total leaves)
# Time spent computing histograms: 0.725s
# Time spent finding best splits:  0.257s
# Time spent applying splits:      0.043s
# Time spent predicting:           0.005s
# Fit 300 trees in 1.298 s, (2270 total leaves)
# Time spent computing histograms: 0.693s
# Time spent finding best splits:  0.232s
# Time spent applying splits:      0.039s
# Time spent predicting:           0.004s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.4s
# Fit 300 trees in 1.420 s, (2332 total leaves)
# Time spent computing histograms: 0.762s
# Time spent finding best splits:  0.258s
# Time spent applying splits:      0.041s
# Time spent predicting:           0.005s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   1.3s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.5s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Fit 300 trees in 1.398 s, (2276 total leaves)
# Time spent computing histograms: 0.761s
# Time spent finding best splits:  0.239s
# Time spent applying splits:      0.043s
# Time spent predicting:           0.005s
# Fit 300 trees in 1.387 s, (2332 total leaves)
# Time spent computing histograms: 0.745s
# Time spent finding best splits:  0.246s
# Time spent applying splits:      0.045s
# Time spent predicting:           0.004s
# Fit 300 trees in 1.425 s, (2270 total leaves)
# Time spent computing histograms: 0.777s
# Time spent finding best splits:  0.242s
# Time spent applying splits:      0.041s
# Time spent predicting:           0.008s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.4s
# Fit 300 trees in 1.404 s, (2288 total leaves)
# Time spent computing histograms: 0.772s
# Time spent finding best splits:  0.242s
# Time spent applying splits:      0.046s
# Time spent predicting:           0.004s
# Fit 300 trees in 1.402 s, (2338 total leaves)
# Time spent computing histograms: 0.783s
# Time spent finding best splits:  0.261s
# Time spent applying splits:      0.051s
# Time spent predicting:           0.004s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.5s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   1.4s
# Fit 300 trees in 1.485 s, (2338 total leaves)
# Time spent computing histograms: 0.792s
# Time spent finding best splits:  0.270s
# Time spent applying splits:      0.044s
# Time spent predicting:           0.004s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.4s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   1.4s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Fit 300 trees in 1.436 s, (2367 total leaves)
# Time spent computing histograms: 0.777s
# Time spent finding best splits:  0.269s
# Time spent applying splits:      0.044s
# Time spent predicting:           0.004s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.5s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   1.5s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Fit 300 trees in 1.417 s, (2288 total leaves)
# Time spent computing histograms: 0.792s
# Time spent finding best splits:  0.242s
# Time spent applying splits:      0.047s
# Time spent predicting:           0.004s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   1.5s
# Binning 0.016 GB of training data: 0.195 s
# Binning 0.002 GB of validation data: 0.007 s
# Fitting gradient boosted rounds:
# Fit 300 trees in 1.527 s, (2276 total leaves)
# Time spent computing histograms: 0.851s
# Time spent finding best splits:  0.269s
# Time spent applying splits:      0.048s
# Time spent predicting:           0.006s
# 0.210 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.206 s
# Binning 0.002 GB of validation data: 0.005 s
# Fitting gradient boosted rounds:
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   1.6s
# Binning 0.016 GB of training data: 0.179 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.182 s
# Binning 0.002 GB of validation data: 0.200 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.007 s
# Fitting gradient boosted rounds:
# 0.196 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.201 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.192 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.196 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.216 s
# Binning 0.002 GB of validation data: 0.006 s
# Fitting gradient boosted rounds:
# 0.207 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Fit 100 trees in 1.134 s, (1500 total leaves)
# Time spent computing histograms: 0.467s
# Time spent finding best splits:  0.326s
# Time spent applying splits:      0.028s
# Time spent predicting:           0.002s
# Fit 100 trees in 1.122 s, (1500 total leaves)
# Time spent computing histograms: 0.471s
# Time spent finding best splits:  0.312s
# Time spent applying splits:      0.028s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.2s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.2s
# Binning 0.016 GB of training data: Fit 100 trees in 1.185 s, (1500 total leaves)
# Time spent computing histograms: 0.516s
# Time spent finding best splits:  0.322s
# Time spent applying splits:      0.031s
# Time spent predicting:           0.002s
# Fit 100 trees in 1.113 s, (1500 total leaves)
# Time spent computing histograms: 0.503s
# Time spent finding best splits:  0.299s
# Time spent applying splits:      0.029s
# Time spent predicting:           0.002s
# Fit 100 trees in 1.115 s, (1500 total leaves)
# Time spent computing histograms: 0.507s
# Time spent finding best splits:  0.276s
# Time spent applying splits:      0.031s
# Time spent predicting:           0.003s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.2s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.1s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.1s
# Fit 100 trees in 1.150 s, (1500 total leaves)
# Time spent computing histograms: 0.524s
# Time spent finding best splits:  0.281s
# Time spent applying splits:      0.027s
# Time spent predicting:           0.003s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.2s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.174 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.208 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.157 s
# Binning 0.002 GB of validation data: 0.005 s
# 0.147 s
# Binning 0.002 GB of validation data: Fitting gradient boosted rounds:
# 0.003 s
# Fitting gradient boosted rounds:
# 0.182 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.198 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Fit 100 trees in 1.454 s, (3100 total leaves)
# Time spent computing histograms: 0.658s
# Time spent finding best splits:  0.424s
# Time spent applying splits:      0.045s
# Time spent predicting:           0.003s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   1.5s
# Binning 0.016 GB of training data: Fit 100 trees in 1.426 s, (3100 total leaves)
# Time spent computing histograms: 0.634s
# Time spent finding best splits:  0.420s
# Time spent applying splits:      0.041s
# Time spent predicting:           0.002s
# Fit 100 trees in 1.523 s, (3100 total leaves)
# Time spent computing histograms: 0.678s
# Time spent finding best splits:  0.439s
# Time spent applying splits:      0.041s
# Time spent predicting:           0.003s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   1.5s
# Fit 100 trees in 1.627 s, (3100 total leaves)
# Time spent computing histograms: 0.699s
# Time spent finding best splits:  0.544s
# Time spent applying splits:      0.045s
# Time spent predicting:           0.003s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   1.6s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   1.7s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Fit 100 trees in 1.688 s, (3100 total leaves)
# Time spent computing histograms: 0.724s
# Time spent finding best splits:  0.563s
# Time spent applying splits:      0.044s
# Time spent predicting:           0.003s
# Fit 100 trees in 1.725 s, (3100 total leaves)
# Time spent computing histograms: 0.757s
# Time spent finding best splits:  0.560s
# Time spent applying splits:      0.047s
# Time spent predicting:           0.003s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   1.7s
# 0.182 s
# Binning 0.002 GB of validation data: 0.005 s
# Fitting gradient boosted rounds:
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   1.8s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.174 s
# Binning 0.002 GB of validation data: 0.005 s
# Fitting gradient boosted rounds:
# 0.171 s
# Binning 0.002 GB of validation data: 0.009 s
# Fitting gradient boosted rounds:
# 0.185 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.165 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.195 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Fit 300 trees in 2.540 s, (4500 total leaves)
# Time spent computing histograms: 1.321s
# Time spent finding best splits:  0.739s
# Time spent applying splits:      0.075s
# Time spent predicting:           0.007s
# Fit 299 trees in 2.623 s, (4485 total leaves)
# Time spent computing histograms: 1.370s
# Time spent finding best splits:  0.731s
# Time spent applying splits:      0.078s
# Time spent predicting:           0.007s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   2.6s
# Fit 300 trees in 2.698 s, (4500 total leaves)
# Time spent computing histograms: 1.347s
# Time spent finding best splits:  0.833s
# Time spent applying splits:      0.082s
# Time spent predicting:           0.007s
# Fit 300 trees in 2.657 s, (4500 total leaves)
# Time spent computing histograms: 1.355s
# Time spent finding best splits:  0.770s
# Time spent applying splits:      0.082s
# Time spent predicting:           0.007s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   2.7s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   2.8s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   2.7s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Fit 300 trees in 2.897 s, (4500 total leaves)
# Time spent computing histograms: 1.416s
# Time spent finding best splits:  0.870s
# Time spent applying splits:      0.079s
# Time spent predicting:           0.009s
# Fit 300 trees in 2.875 s, (4500 total leaves)
# Time spent computing histograms: 1.425s
# Time spent finding best splits:  0.891s
# Time spent applying splits:      0.081s
# Time spent predicting:           0.007s
# 0.210 s
# Binning 0.002 GB of validation data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   3.0s
# 0.187 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.007 s
# Fitting gradient boosted rounds:
# 0.176 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   2.9s
# Binning 0.016 GB of training data: 0.218 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Binning 0.016 GB of training data: 0.197 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.187 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Fit 100 trees in 0.747 s, (789 total leaves)
# Time spent computing histograms: 0.302s
# Time spent finding best splits:  0.148s
# Time spent applying splits:      0.014s
# Time spent predicting:           0.001s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   0.8s
# Fit 100 trees in 0.717 s, (776 total leaves)
# Time spent computing histograms: 0.302s
# Time spent finding best splits:  0.149s
# Time spent applying splits:      0.017s
# Time spent predicting:           0.002s
# Fit 100 trees in 0.749 s, (798 total leaves)
# Time spent computing histograms: 0.314s
# Time spent finding best splits:  0.158s
# Time spent applying splits:      0.016s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   0.7s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   0.8s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Fit 100 trees in 0.776 s, (793 total leaves)
# Time spent computing histograms: 0.309s
# Time spent finding best splits:  0.150s
# Time spent applying splits:      0.014s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   0.8s
# Binning 0.016 GB of training data: Fit 100 trees in 0.680 s, (774 total leaves)
# Time spent computing histograms: 0.273s
# Time spent finding best splits:  0.140s
# Time spent applying splits:      0.014s
# Time spent predicting:           0.001s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   0.7s
# Fit 100 trees in 0.732 s, (788 total leaves)
# Time spent computing histograms: 0.292s
# Time spent finding best splits:  0.150s
# Time spent applying splits:      0.018s
# Time spent predicting:           0.002s
# 0.177 s
# Binning 0.002 GB of validation data: 0.184 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.003 s
# Fitting gradient boosted rounds:
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   0.8s
# 0.212 s
# Binning 0.002 GB of validation data: 0.007 s
# Fitting gradient boosted rounds:
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.194 s
# Binning 0.002 GB of validation data: 0.005 s
# Fitting gradient boosted rounds:
# 0.169 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Fit 250 trees in 3.249 s, (7750 total leaves)
# Time spent computing histograms: 1.589s
# Time spent finding best splits:  1.058s
# Time spent applying splits:      0.108s
# Time spent predicting:           0.006s
# 0.197 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   3.3s
# Binning 0.016 GB of training data: Fit 260 trees in 3.533 s, (8060 total leaves)
# Time spent computing histograms: 1.739s
# Time spent finding best splits:  1.137s
# Time spent applying splits:      0.117s
# Time spent predicting:           0.007s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   3.6s
# 0.163 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Binning 0.016 GB of training data: Fit 100 trees in 0.712 s, (793 total leaves)
# Time spent computing histograms: 0.300s
# Time spent finding best splits:  0.152s
# Time spent applying splits:      0.017s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   0.7s
# Fit 100 trees in 0.774 s, (789 total leaves)
# Time spent computing histograms: 0.318s
# Time spent finding best splits:  0.150s
# Time spent applying splits:      0.018s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   0.8s
# Binning 0.016 GB of training data: Fit 100 trees in 0.790 s, (798 total leaves)
# Time spent computing histograms: 0.334s
# Time spent finding best splits:  0.172s
# Time spent applying splits:      0.018s
# Time spent predicting:           0.002s
# Fit 100 trees in 0.753 s, (776 total leaves)
# Time spent computing histograms: 0.308s
# Time spent finding best splits:  0.154s
# Time spent applying splits:      0.016s
# Time spent predicting:           0.002s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   0.8s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   0.8s
# Binning 0.016 GB of training data: Fit 255 trees in 3.809 s, (7905 total leaves)
# Time spent computing histograms: 1.772s
# Time spent finding best splits:  1.398s
# Time spent applying splits:      0.114s
# Time spent predicting:           0.007s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   3.9s
# Fit 100 trees in 0.721 s, (788 total leaves)
# Time spent computing histograms: 0.303s
# Time spent finding best splits:  0.150s
# Time spent applying splits:      0.016s
# Time spent predicting:           0.001s
# 0.208 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   0.7s
# 0.170 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Fit 100 trees in 0.723 s, (774 total leaves)
# Time spent computing histograms: 0.291s
# Time spent finding best splits:  0.147s
# Time spent applying splits:      0.015s
# Time spent predicting:           0.001s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   0.7s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.189 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.193 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.213 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.157 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.183 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.184 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Fit 300 trees in 4.105 s, (9300 total leaves)
# Time spent computing histograms: 2.045s
# Time spent finding best splits:  1.356s
# Time spent applying splits:      0.140s
# Time spent predicting:           0.008s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   4.2s
# Binning 0.016 GB of training data: Fit 300 trees in 4.476 s, (9300 total leaves)
# Time spent computing histograms: 2.109s
# Time spent finding best splits:  1.630s
# Time spent applying splits:      0.128s
# Time spent predicting:           0.008s
# Fit 295 trees in 4.393 s, (9145 total leaves)
# Time spent computing histograms: 2.052s
# Time spent finding best splits:  1.621s
# Time spent applying splits:      0.129s
# Time spent predicting:           0.008s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   4.6s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=128, max_depth=None, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   4.5s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.164 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.158 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.214 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Fit 300 trees in 1.738 s, (2331 total leaves)
# Time spent computing histograms: 0.875s
# Time spent finding best splits:  0.442s
# Time spent applying splits:      0.049s
# Time spent predicting:           0.006s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.8s
# Binning 0.016 GB of training data: Fit 300 trees in 1.674 s, (2322 total leaves)
# Time spent computing histograms: 0.815s
# Time spent finding best splits:  0.414s
# Time spent applying splits:      0.044s
# Time spent predicting:           0.005s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.7s
# Binning 0.016 GB of training data: Fit 300 trees in 1.616 s, (2279 total leaves)
# Time spent computing histograms: 0.792s
# Time spent finding best splits:  0.385s
# Time spent applying splits:      0.041s
# Time spent predicting:           0.005s
# Fit 300 trees in 1.700 s, (2353 total leaves)
# Time spent computing histograms: 0.845s
# Time spent finding best splits:  0.447s
# Time spent applying splits:      0.045s
# Time spent predicting:           0.006s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.7s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.7s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.201 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Fit 300 trees in 1.689 s, (2277 total leaves)
# Time spent computing histograms: 0.858s
# Time spent finding best splits:  0.406s
# Time spent applying splits:      0.041s
# Time spent predicting:           0.006s
# Fit 300 trees in 1.744 s, (2280 total leaves)
# Time spent computing histograms: 0.883s
# Time spent finding best splits:  0.423s
# Time spent applying splits:      0.046s
# Time spent predicting:           0.007s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.8s
# Fit 300 trees in 1.606 s, (2331 total leaves)
# Time spent computing histograms: 0.775s
# Time spent finding best splits:  0.422s
# Time spent applying splits:      0.046s
# Time spent predicting:           0.004s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.7s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   1.7s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.174 s
# Binning 0.002 GB of validation data: Fit 300 trees in 1.645 s, (2322 total leaves)
# Time spent computing histograms: 0.811s
# Time spent finding best splits:  0.437s
# Time spent applying splits:      0.042s
# Time spent predicting:           0.005s
# 0.004 s
# Fitting gradient boosted rounds:
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   1.7s
# Fit 300 trees in 1.670 s, (2353 total leaves)
# Time spent computing histograms: 0.824s
# Time spent finding best splits:  0.429s
# Time spent applying splits:      0.042s
# Time spent predicting:           0.005s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   1.7s
# Binning 0.016 GB of training data: 0.172 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.169 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Binning 0.016 GB of training data: 0.155 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.181 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.234 s
# Binning 0.002 GB of validation data: 0.006 s
# Fitting gradient boosted rounds:
# 0.200 s
# Binning 0.002 GB of validation data: 0.174 s
# Binning 0.002 GB of validation data: 0.006 s
# Fitting gradient boosted rounds:
# 0.003 s
# Fitting gradient boosted rounds:
# Fit 300 trees in 1.672 s, (2280 total leaves)
# Time spent computing histograms: 0.852s
# Time spent finding best splits:  0.408s
# Time spent applying splits:      0.043s
# Time spent predicting:           0.005s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   1.7s
# Binning 0.016 GB of training data: Fit 300 trees in 1.640 s, (2279 total leaves)
# Time spent computing histograms: 0.801s
# Time spent finding best splits:  0.389s
# Time spent applying splits:      0.041s
# Time spent predicting:           0.004s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   1.7s
# Binning 0.016 GB of training data: Fit 300 trees in 1.748 s, (2277 total leaves)
# Time spent computing histograms: 0.889s
# Time spent finding best splits:  0.427s
# Time spent applying splits:      0.044s
# Time spent predicting:           0.005s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   1.8s
# Binning 0.016 GB of training data: 0.225 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.169 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.234 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Fit 100 trees in 1.549 s, (1500 total leaves)
# Time spent computing histograms: 0.641s
# Time spent finding best splits:  0.532s
# Time spent applying splits:      0.031s
# Time spent predicting:           0.003s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.6s
# Binning 0.016 GB of training data: Fit 100 trees in 1.497 s, (1500 total leaves)
# Time spent computing histograms: 0.623s
# Time spent finding best splits:  0.539s
# Time spent applying splits:      0.030s
# Time spent predicting:           0.004s
# Fit 100 trees in 1.441 s, (1500 total leaves)
# Time spent computing histograms: 0.613s
# Time spent finding best splits:  0.484s
# Time spent applying splits:      0.033s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.5s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.5s
# Fit 100 trees in 1.482 s, (1500 total leaves)
# Time spent computing histograms: 0.619s
# Time spent finding best splits:  0.518s
# Time spent applying splits:      0.031s
# Time spent predicting:           0.002s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Fit 100 trees in 1.413 s, (1500 total leaves)
# Time spent computing histograms: 0.632s
# Time spent finding best splits:  0.473s
# Time spent applying splits:      0.029s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.5s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.4s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.194 s
# Binning 0.002 GB of validation data: Fit 100 trees in 1.542 s, (1500 total leaves)
# Time spent computing histograms: 0.665s
# Time spent finding best splits:  0.476s
# Time spent applying splits:      0.031s
# Time spent predicting:           0.003s
# 0.009 s
# Fitting gradient boosted rounds:
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.6s
# 0.192 s
# Binning 0.002 GB of validation data: 0.005 s
# Fitting gradient boosted rounds:
# Binning 0.016 GB of training data: 0.206 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.192 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.211 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.227 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# Fit 100 trees in 2.422 s, (3100 total leaves)
# Time spent computing histograms: 1.026s
# Time spent finding best splits:  0.925s
# Time spent applying splits:      0.050s
# Time spent predicting:           0.003s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   2.5s
# Binning 0.016 GB of training data: Fit 100 trees in 2.526 s, (3100 total leaves)
# Time spent computing histograms: 1.065s
# Time spent finding best splits:  1.002s
# Time spent applying splits:      0.050s
# Time spent predicting:           0.004s
# Fit 100 trees in 2.567 s, (3100 total leaves)
# Time spent computing histograms: 1.084s
# Time spent finding best splits:  0.976s
# Time spent applying splits:      0.055s
# Time spent predicting:           0.005s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   2.6s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   2.6s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.205 s
# Binning 0.002 GB of validation data: 0.005 s
# Fit 100 trees in 2.213 s, (3100 total leaves)
# Time spent computing histograms: 0.968s
# Time spent finding best splits:  0.767s
# Time spent applying splits:      0.054s
# Time spent predicting:           0.003s
# Fitting gradient boosted rounds:
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   2.3s
# Fit 100 trees in 2.129 s, (3100 total leaves)
# Time spent computing histograms: 0.949s
# Time spent finding best splits:  0.773s
# Time spent applying splits:      0.056s
# Time spent predicting:           0.003s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   2.2s
# Binning 0.016 GB of training data: Fit 100 trees in 2.140 s, (3100 total leaves)
# Time spent computing histograms: 0.934s
# Time spent finding best splits:  0.729s
# Time spent applying splits:      0.046s
# Time spent predicting:           0.003s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   2.2s
# 0.246 s
# Binning 0.002 GB of validation data: 0.003 s
# 0.244 s
# Binning 0.002 GB of validation data: Fitting gradient boosted rounds:
# 0.004 s
# Fitting gradient boosted rounds:
# Binning 0.016 GB of training data: 0.232 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.240 s
# Binning 0.002 GB of validation data: 0.006 s
# Fitting gradient boosted rounds:
# 0.249 s
# Binning 0.002 GB of validation data: 0.010 s
# Fitting gradient boosted rounds:
# Fit 300 trees in 3.900 s, (4500 total leaves)
# Time spent computing histograms: 1.848s
# Time spent finding best splits:  1.353s
# Time spent applying splits:      0.102s
# Time spent predicting:           0.009s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   4.0s
# Fit 300 trees in 4.089 s, (4500 total leaves)
# Time spent computing histograms: 1.838s
# Time spent finding best splits:  1.540s
# Time spent applying splits:      0.096s
# Time spent predicting:           0.007s
# Fit 300 trees in 3.966 s, (4500 total leaves)
# Time spent computing histograms: 1.864s
# Time spent finding best splits:  1.386s
# Time spent applying splits:      0.111s
# Time spent predicting:           0.008s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   4.2s
# Fit 300 trees in 4.093 s, (4500 total leaves)
# Time spent computing histograms: 1.835s
# Time spent finding best splits:  1.545s
# Time spent applying splits:      0.096s
# Time spent predicting:           0.011s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   4.1s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Fit 300 trees in 3.961 s, (4500 total leaves)
# Time spent computing histograms: 1.836s
# Time spent finding best splits:  1.397s
# Time spent applying splits:      0.100s
# Time spent predicting:           0.008s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   4.2s
# Fit 300 trees in 4.214 s, (4500 total leaves)
# Time spent computing histograms: 1.893s
# Time spent finding best splits:  1.595s
# Time spent applying splits:      0.104s
# Time spent predicting:           0.008s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   4.0s
# Binning 0.016 GB of training data: 0.191 s
# Binning 0.002 GB of validation data: 0.005 s
# Fitting gradient boosted rounds:
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.05, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   4.3s
# Binning 0.016 GB of training data: 0.199 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.204 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.195 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.213 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.200 s
# Binning 0.002 GB of validation data: 0.009 s
# Fitting gradient boosted rounds:
# Fit 100 trees in 0.648 s, (781 total leaves)
# Time spent computing histograms: 0.275s
# Time spent finding best splits:  0.092s
# Time spent applying splits:      0.017s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.1, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   0.7s
# Binning 0.016 GB of training data: Fit 100 trees in 0.655 s, (787 total leaves)
# Time spent computing histograms: 0.271s
# Time spent finding best splits:  0.089s
# Time spent applying splits:      0.014s
# Time spent predicting:           0.001s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.1, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   0.7s
# Fit 100 trees in 0.671 s, (789 total leaves)
# Time spent computing histograms: 0.270s
# Time spent finding best splits:  0.092s
# Time spent applying splits:      0.017s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.0, learning_rate=0.1, max_bins=128, max_depth=3, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   0.7s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Fit 100 trees in 0.659 s, (766 total leaves)
# Time spent computing histograms: 0.277s
# Time spent finding best splits:  0.084s
# ...
# Time spent finding best splits:  0.517s
# Time spent applying splits:      0.057s
# Time spent predicting:           0.005s
# Fit 300 trees in 2.048 s, (2240 total leaves)
# Time spent computing histograms: 1.007s
# Time spent finding best splits:  0.493s
# Time spent applying splits:      0.056s
# Time spent predicting:           0.005s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   2.0s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   2.1s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   2.2s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   2.1s
# Fit 300 trees in 2.041 s, (2250 total leaves)
# Time spent computing histograms: 0.990s
# Time spent finding best splits:  0.473s
# Time spent applying splits:      0.056s
# Time spent predicting:           0.006s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   2.1s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: Fit 300 trees in 2.115 s, (2312 total leaves)
# Time spent computing histograms: 0.999s
# Time spent finding best splits:  0.538s
# Time spent applying splits:      0.053s
# Time spent predicting:           0.010s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   2.2s
# Binning 0.016 GB of training data: 0.261 s
# Binning 0.002 GB of validation data: 0.007 s
# Fitting gradient boosted rounds:
# 0.223 s
# Binning 0.002 GB of validation data: 0.241 s
# Binning 0.002 GB of validation data: 0.006 s
# Fitting gradient boosted rounds:
# 0.003 s
# Fitting gradient boosted rounds:
# 0.241 s
# Binning 0.002 GB of validation data: 0.003 s
# 0.229 s
# Binning 0.002 GB of validation data: Fitting gradient boosted rounds:
# 0.004 s
# Fitting gradient boosted rounds:
# 0.242 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.227 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# Fit 300 trees in 2.044 s, (2240 total leaves)
# Time spent computing histograms: 1.003s
# Time spent finding best splits:  0.493s
# Time spent applying splits:      0.048s
# Time spent predicting:           0.006s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   2.1s
# Fit 300 trees in 2.140 s, (2301 total leaves)
# Time spent computing histograms: 1.044s
# Time spent finding best splits:  0.519s
# Time spent applying splits:      0.055s
# Time spent predicting:           0.006s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   2.2s
# Fit 300 trees in 2.136 s, (2325 total leaves)
# Time spent computing histograms: 1.082s
# Time spent finding best splits:  0.528s
# Time spent applying splits:      0.051s
# Time spent predicting:           0.008s
# Fit 300 trees in 2.071 s, (2250 total leaves)
# Time spent computing histograms: 1.008s
# Time spent finding best splits:  0.486s
# Time spent applying splits:      0.060s
# Time spent predicting:           0.008s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   2.2s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   2.1s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Fit 300 trees in 2.101 s, (2257 total leaves)
# Time spent computing histograms: 1.036s
# Time spent finding best splits:  0.484s
# Time spent applying splits:      0.056s
# Time spent predicting:           0.006s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=3, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   2.2s
# Binning 0.016 GB of training data: 0.248 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.219 s
# Binning 0.002 GB of validation data: 0.240 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.008 s
# Fitting gradient boosted rounds:
# 0.243 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# 0.228 s
# Binning 0.002 GB of validation data: 0.006 s
# Fitting gradient boosted rounds:
# Fit 100 trees in 1.646 s, (1500 total leaves)
# Time spent computing histograms: 0.679s
# Time spent finding best splits:  0.523s
# Time spent applying splits:      0.033s
# Time spent predicting:           0.002s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.7s
# Fit 100 trees in 1.728 s, (1500 total leaves)
# Time spent computing histograms: 0.741s
# Time spent finding best splits:  0.539s
# Time spent applying splits:      0.038s
# Time spent predicting:           0.003s
# Fit 100 trees in 1.750 s, (1500 total leaves)
# Time spent computing histograms: 0.712s
# Time spent finding best splits:  0.602s
# Time spent applying splits:      0.040s
# Time spent predicting:           0.002s
# Fit 100 trees in 1.840 s, (1500 total leaves)
# Time spent computing histograms: 0.730s
# Time spent finding best splits:  0.629s
# Time spent applying splits:      0.049s
# Time spent predicting:           0.003s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.9s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.8s
# Fit 100 trees in 1.784 s, (1500 total leaves)
# Time spent computing histograms: 0.728s
# Time spent finding best splits:  0.616s
# Time spent applying splits:      0.044s
# Time spent predicting:           0.003s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.8s
# Fit 100 trees in 1.787 s, (1500 total leaves)
# Time spent computing histograms: 0.738s
# Time spent finding best splits:  0.594s
# Time spent applying splits:      0.046s
# Time spent predicting:           0.003s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=20; total time=   1.8s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=15, min_samples_leaf=50; total time=   1.8s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.271 s
# Binning 0.002 GB of validation data: 0.006 s
# Fitting gradient boosted rounds:
# 0.254 s
# Binning 0.002 GB of validation data: 0.007 s
# Fitting gradient boosted rounds:
# 0.229 s
# Binning 0.002 GB of validation data: 0.224 s
# Binning 0.002 GB of validation data: 0.007 s
# Fitting gradient boosted rounds:
# 0.009 s
# Fitting gradient boosted rounds:
# 0.274 s
# Binning 0.002 GB of validation data: 0.007 s
# Fitting gradient boosted rounds:
# 0.291 s
# Binning 0.002 GB of validation data: 0.006 s
# Fitting gradient boosted rounds:
# Fit 100 trees in 2.907 s, (3100 total leaves)
# Time spent computing histograms: 1.217s
# Time spent finding best splits:  1.122s
# Time spent applying splits:      0.064s
# Time spent predicting:           0.003s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   3.0s
# Binning 0.016 GB of training data: Fit 100 trees in 2.651 s, (3100 total leaves)
# Time spent computing histograms: 1.164s
# Time spent finding best splits:  0.959s
# Time spent applying splits:      0.065s
# Time spent predicting:           0.003s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   2.7s
# Binning 0.016 GB of training data: Fit 100 trees in 2.766 s, (3100 total leaves)
# Time spent computing histograms: 1.226s
# Time spent finding best splits:  0.997s
# Time spent applying splits:      0.073s
# Time spent predicting:           0.003s
# 0.207 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   2.8s
# Fit 100 trees in 2.705 s, (3100 total leaves)Binning 0.016 GB of training data:
# Time spent computing histograms: 1.180s
# Time spent finding best splits:  0.948s
# Time spent applying splits:      0.070s
# Time spent predicting:           0.005s
# Fit 100 trees in 2.988 s, (3100 total leaves)
# Time spent computing histograms: 1.264s
# Time spent finding best splits:  1.141s
# Time spent applying splits:      0.063s
# Time spent predicting:           0.003s
# Fit 100 trees in 2.983 s, (3100 total leaves)
# Time spent computing histograms: 1.234s
# Time spent finding best splits:  1.156s
# Time spent applying splits:      0.070s
# Time spent predicting:           0.003s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=50; total time=   2.8s
# 0.256 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   3.1s
# Binning 0.016 GB of training data: [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=100, max_leaf_nodes=31, min_samples_leaf=20; total time=   3.0s
# Binning 0.016 GB of training data: Binning 0.016 GB of training data: 0.247 s
# Binning 0.002 GB of validation data: 0.009 s
# Fitting gradient boosted rounds:
# 0.224 s
# Binning 0.002 GB of validation data: 0.005 s
# Fitting gradient boosted rounds:
# 0.208 s
# Binning 0.002 GB of validation data: 0.006 s
# Fitting gradient boosted rounds:
# 0.277 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# Fit 238 trees in 3.701 s, (3570 total leaves)
# Time spent computing histograms: 1.673s
# Time spent finding best splits:  1.256s
# Time spent applying splits:      0.095s
# Time spent predicting:           0.007s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   3.8s
# Fit 254 trees in 3.750 s, (3810 total leaves)
# Time spent computing histograms: 1.734s
# Time spent finding best splits:  1.323s
# Time spent applying splits:      0.093s
# Time spent predicting:           0.006s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   3.8s
# Fit 261 trees in 3.919 s, (3915 total leaves)
# Time spent computing histograms: 1.821s
# Time spent finding best splits:  1.327s
# Time spent applying splits:      0.093s
# Time spent predicting:           0.006s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=50; total time=   4.0s
# Fit 262 trees in 4.107 s, (3930 total leaves)
# Time spent computing histograms: 1.785s
# Time spent finding best splits:  1.558s
# Time spent applying splits:      0.094s
# Time spent predicting:           0.008s
# Fit 253 trees in 4.100 s, (3795 total leaves)
# Time spent computing histograms: 1.842s
# Time spent finding best splits:  1.510s
# Time spent applying splits:      0.099s
# Time spent predicting:           0.007s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   4.2s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   4.2s
# Fit 296 trees in 4.621 s, (4440 total leaves)
# Time spent computing histograms: 2.029s
# Time spent finding best splits:  1.729s
# Time spent applying splits:      0.105s
# Time spent predicting:           0.008s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=15, min_samples_leaf=20; total time=   4.7s
# Fit 160 trees in 3.475 s, (4960 total leaves)
# Time spent computing histograms: 1.539s
# Time spent finding best splits:  1.310s
# Time spent applying splits:      0.091s
# Time spent predicting:           0.005s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   3.5s
# Fit 162 trees in 3.572 s, (5022 total leaves)
# Time spent computing histograms: 1.519s
# Time spent finding best splits:  1.333s
# Time spent applying splits:      0.091s
# Time spent predicting:           0.005s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   3.6s
# Fit 174 trees in 4.302 s, (5394 total leaves)
# Time spent computing histograms: 1.814s
# Time spent finding best splits:  1.751s
# Time spent applying splits:      0.100s
# Time spent predicting:           0.007s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   4.4s
# Fit 166 trees in 4.060 s, (5146 total leaves)
# Time spent computing histograms: 1.684s
# Time spent finding best splits:  1.623s
# Time spent applying splits:      0.094s
# Time spent predicting:           0.005s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   4.1s
# Fit 200 trees in 4.123 s, (6200 total leaves)
# Time spent computing histograms: 1.834s
# Time spent finding best splits:  1.555s
# Time spent applying splits:      0.095s
# Time spent predicting:           0.006s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=31, min_samples_leaf=50; total time=   4.2s
# Fit 202 trees in 4.707 s, (6262 total leaves)
# Time spent computing histograms: 1.960s
# Time spent finding best splits:  1.917s
# Time spent applying splits:      0.097s
# Time spent predicting:           0.008s
# [CV] END early_stopping=True, l2_regularization=0.1, learning_rate=0.1, max_bins=255, max_depth=None, max_iter=300, max_leaf_nodes=31, min_samples_leaf=20; total time=   4.8s
# Binning 0.024 GB of training data: 0.085 s
# Binning 0.003 GB of validation data: 0.013 s
# Fitting gradient boosted rounds:
# Fit 279 trees in 4.280 s, (8649 total leaves)
# Time spent computing histograms: 1.879s
# Time spent finding best splits:  0.974s
# Time spent applying splits:      0.933s
# Time spent predicting:           0.021s

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]
    
    print("\n=== Final Test Set Performance ===")
    print(f"ROC AUC: {roc_auc_score(y_test, y_proba):.4f}")
    print(classification_report(y_test, y_pred))
    
    # Confusion Matrix
    plt.figure(figsize=(8, 6))
    ConfusionMatrixDisplay.from_estimator(model, X_test, y_test, cmap='Blues')
    plt.title('Test Set Confusion Matrix')
    plt.show()
    
    # ROC Curve
    fpr, tpr, _ = roc_curve(y_test, y_proba)
    roc_auc = auc(fpr, tpr)
    
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2,
             label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.title('Test Set ROC Curve')
    plt.legend(loc="lower right")
    plt.show()
    
    return y_proba

y_proba = evaluate_model(best_model, X_test, y_test)
# Out:
# === Final Test Set Performance ===
# ROC AUC: 0.9954
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      1638
#            1       0.97      0.96      0.97      1639
#
#     accuracy                           0.97      3277
#    macro avg       0.97      0.97      0.97      3277
# weighted avg       0.97      0.97      0.97      3277

# %%
def plot_learning_curve(model):
    # Extract training history from the best model
    train_loss = model.train_score_
    val_loss = model.validation_score_
    
    plt.figure(figsize=(12, 6))
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Learning Curve')
    plt.xlabel('Iterations')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

plot_learning_curve(best_model)

# %%
print("\n=== Nested Cross-Validation ===")
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Using only train-val data for CV
cv_scores = cross_validate(
    grid_search.best_estimator_,
    X_trainval,
    y_trainval,
    cv=outer_cv,
    scoring=['roc_auc', 'accuracy', 'f1'],
    return_train_score=True,
    n_jobs=-1
)
# Out:
# === Nested Cross-Validation ===
# Binning 0.019 GB of training data: Binning 0.019 GB of training data: Binning 0.019 GB of training data: Binning 0.019 GB of training data: Binning 0.019 GB of training data: 0.163 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.161 s
# Binning 0.002 GB of validation data: 0.162 s
# Binning 0.002 GB of validation data: 0.165 s
# Binning 0.002 GB of validation data: 0.003 s
# Fitting gradient boosted rounds:
# 0.003 s
# Fitting gradient boosted rounds:
# 0.003 s
# Fitting gradient boosted rounds:
# 0.159 s
# Binning 0.002 GB of validation data: 0.004 s
# Fitting gradient boosted rounds:
# Fit 152 trees in 1.798 s, (4712 total leaves)
# Time spent computing histograms: 0.808s
# Time spent finding best splits:  0.566s
# Time spent applying splits:      0.048s
# Time spent predicting:           0.003s
# Fit 170 trees in 1.971 s, (5270 total leaves)
# Time spent computing histograms: 0.903s
# Time spent finding best splits:  0.633s
# Time spent applying splits:      0.053s
# Time spent predicting:           0.004s
# Fit 172 trees in 1.982 s, (5332 total leaves)
# Time spent computing histograms: 0.912s
# Time spent finding best splits:  0.635s
# Time spent applying splits:      0.053s
# Time spent predicting:           0.004s
# Fit 201 trees in 2.268 s, (6231 total leaves)
# Time spent computing histograms: 1.055s
# Time spent finding best splits:  0.736s
# Time spent applying splits:      0.064s
# Time spent predicting:           0.004s
# Fit 213 trees in 2.399 s, (6603 total leaves)
# Time spent computing histograms: 1.117s
# Time spent finding best splits:  0.781s
# Time spent applying splits:      0.067s
# Time spent predicting:           0.005s

# %%
print(f"Validation ROC AUC: {np.mean(cv_scores['test_roc_auc']):.4f} (±{np.std(cv_scores['test_roc_auc']):.4f})")
print(f"Validation F1: {np.mean(cv_scores['test_f1']):.4f}")
# Out:
# Validation ROC AUC: 0.9909 (±0.0012)
# Validation F1: 0.9532

# %%
print("\n=== Optimal Hyperparameters ===")
print(grid_search.best_params_)
# Out:
# === Optimal Hyperparameters ===
# {'early_stopping': True, 'l2_regularization': 0.0, 'learning_rate': 0.1, 'max_bins': 128, 'max_depth': None, 'max_iter': 300, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}

# %%
import shap

def shap_analysis(model, X, sample_size=1000):
    """Generate SHAP plots to explain model predictions"""
    print("\n=== SHAP Analysis ===")
    
    X_sample = X.sample(max(sample_size, len(X)), random_state=42)
    
    # Create explainer and calculate SHAP values
    explainer = shap.TreeExplainer(model)
    shap_values = explainer(X_sample)
    
    # Global feature importance
    plt.figure(figsize=(10, 6))
    shap.plots.bar(shap_values, show=False)
    plt.title("Global Feature Importance")
    plt.tight_layout()
    plt.show()
    
    # Individual sample explanation (first sample in the set)
    plt.figure(figsize=(10, 6))
    shap.plots.waterfall(shap_values[0], show=False)
    plt.title("Individual Prediction Explanation")
    plt.tight_layout()
    plt.show()

shap_analysis(best_model, X_test, sample_size=1000)
# Out:
# === SHAP Analysis ===

# %%
def shap_analysis(model, X):
    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X)
    
    plt.figure(figsize=(12, 8))
    shap.summary_plot(shap_values, X, show=False)
    plt.title('SHAP Value Distribution')
    plt.show()
shap_analysis(best_model, X_test)
